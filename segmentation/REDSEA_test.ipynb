# %%
'/mnt/jwh83-data/Confetti/data/CODEX/new/done/B004-A-304.tif'

'/mnt/jwh83-data/Confetti/output/intestine_data_mask_outputs/MicroSAM/B004-A-304-msamtf.tif'

'/mnt/jwh83-data/Confetti/data/CODEX/ns_mp_codex_channel_list.csv'

'/mnt/jwh83-data/Confetti/output/Redsea/MicroSAM/20251028_B004-A-304-RedseaTest/'

# %%
# !redsea \
  /mnt/jwh83-data/Confetti/data/CODEX/new/done/B004-A-304.tif \
  /mnt/jwh83-data/Confetti/output/intestine_data_mask_outputs/MicroSAM/B004-A-304-msamtif.tif \
  /mnt/jwh83-data/Confetti/data/CODEX/ns_mp_codex_channel_list.csv \
  /mnt/jwh83-data/Confetti/output/Redsea/MicroSAM/ \
  --element-shape star \
  --element-size 2
# Out:
# MainProcess 2025-10-28 16:49:48,956 INFO: Reading image
# MainProcess 2025-10-28 16:50:26,909 INFO: Reading segmentation mask
# MainProcess 2025-10-28 18:00:48,113 INFO: Quantifying markers before correction
# MainProcess 2025-10-28 18:00:52,216 INFO: Creating cell-cell contact matrix
# MainProcess 2025-10-28 18:04:48,585 INFO: Performing correction
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# MainProcess 2025-10-28 18:47:43,046 INFO: Writing output files to /mnt/jwh83-data/Confetti/output/Redsea/MicroSAM
# MainProcess 2025-10-28 18:47:44,679 INFO: Done

# %%
# !redsea \
  /mnt/jwh83-data/Confetti/data/CODEX/new/done/B004-A-004.tif \
  /mnt/jwh83-data/Confetti/output/intestine_data_mask_outputs/MicroSAM/B004-A-004-msamtif.tif \
  /mnt/jwh83-data/Confetti/data/CODEX/ns_mp_codex_channel_list.csv \
  /mnt/jwh83-data/Confetti/output/Redsea/MicroSAM/B004-A-004 \
  --element-shape star \
  --element-size 2
# Out:
# MainProcess 2025-11-13 17:51:37,794 INFO: Reading image
# MainProcess 2025-11-13 17:52:20,202 INFO: Reading segmentation mask
# MainProcess 2025-11-13 18:59:49,140 INFO: Quantifying markers before correction
# MainProcess 2025-11-13 18:59:53,249 INFO: Creating cell-cell contact matrix
# MainProcess 2025-11-13 19:03:45,606 INFO: Performing correction
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# MainProcess 2025-11-13 19:34:14,171 INFO: Writing output files to /mnt/jwh83-data/Confetti/output/Redsea/MicroSAM/B004-A-004
# MainProcess 2025-11-13 19:34:15,335 INFO: Done

# %%
# !redsea \
  /mnt/jwh83-data/Confetti/data/CODEX/new/done/B004-A-008.tif \
  /mnt/jwh83-data/Confetti/output/intestine_data_mask_outputs/MicroSAM/B004-A-008-msamtif.tif \
  /mnt/jwh83-data/Confetti/data/CODEX/ns_mp_codex_channel_list.csv \
  /mnt/jwh83-data/Confetti/output/Redsea/MicroSAM/B004-A-008 \
  --element-shape star \
  --element-size 2
# Out:
# MainProcess 2025-11-13 19:34:15,844 INFO: Reading image
# MainProcess 2025-11-13 19:34:56,695 INFO: Reading segmentation mask
# MainProcess 2025-11-13 21:06:27,641 INFO: Quantifying markers before correction
# MainProcess 2025-11-13 21:06:33,024 INFO: Creating cell-cell contact matrix
# MainProcess 2025-11-13 21:10:28,447 INFO: Performing correction
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# MainProcess 2025-11-13 22:20:45,834 INFO: Writing output files to /mnt/jwh83-data/Confetti/output/Redsea/MicroSAM/B004-A-008
# MainProcess 2025-11-13 22:21:23,640 INFO: Done

# %%
# !redsea \
  /mnt/jwh83-data/Confetti/data/CODEX/new/done/B004-A-104.tif \
  /mnt/jwh83-data/Confetti/output/intestine_data_mask_outputs/MicroSAM/B004-A-104-msamtif.tif \
  /mnt/jwh83-data/Confetti/data/CODEX/ns_mp_codex_channel_list.csv \
  /mnt/jwh83-data/Confetti/output/Redsea/MicroSAM/B004-A-104 \
  --element-shape star \
  --element-size 2
# Out:
# MainProcess 2025-11-13 22:21:24,149 INFO: Reading image
# MainProcess 2025-11-13 22:22:05,143 INFO: Reading segmentation mask
# MainProcess 2025-11-14 00:11:39,934 INFO: Quantifying markers before correction
# MainProcess 2025-11-14 00:11:46,874 INFO: Creating cell-cell contact matrix
# MainProcess 2025-11-14 00:15:53,898 INFO: Performing correction
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# MainProcess 2025-11-14 01:35:23,147 INFO: Writing output files to /mnt/jwh83-data/Confetti/output/Redsea/MicroSAM/B004-A-104
# MainProcess 2025-11-14 01:36:01,410 INFO: Done

# %%
# !redsea \
  /mnt/jwh83-data/Confetti/data/CODEX/new/done/B004-A-204.tif \
  /mnt/jwh83-data/Confetti/output/intestine_data_mask_outputs/MicroSAM/B004-A-204-msamtif.tif \
  /mnt/jwh83-data/Confetti/data/CODEX/ns_mp_codex_channel_list.csv \
  /mnt/jwh83-data/Confetti/output/Redsea/MicroSAM/B004-A-204 \
  --element-shape star \
  --element-size 2
# Out:
# MainProcess 2025-11-14 01:36:01,953 INFO: Reading image
# MainProcess 2025-11-14 01:36:42,269 INFO: Reading segmentation mask
# MainProcess 2025-11-14 02:43:24,634 INFO: Quantifying markers before correction
# MainProcess 2025-11-14 02:43:28,604 INFO: Creating cell-cell contact matrix
# MainProcess 2025-11-14 02:47:27,362 INFO: Performing correction
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# MainProcess 2025-11-14 03:37:01,272 INFO: Writing output files to /mnt/jwh83-data/Confetti/output/Redsea/MicroSAM/B004-A-204
# MainProcess 2025-11-14 03:37:38,538 INFO: Done

# %%
# !redsea \
  /mnt/jwh83-data/Confetti/data/CODEX/new/done/B004-A-404.tif \
  /mnt/jwh83-data/Confetti/output/intestine_data_mask_outputs/MicroSAM/B004-A-404-msamtif.tif \
  /mnt/jwh83-data/Confetti/data/CODEX/ns_mp_codex_channel_list.csv \
  /mnt/jwh83-data/Confetti/output/Redsea/MicroSAM/B004-A-404 \
  --element-shape star \
  --element-size 2
# Out:
# MainProcess 2025-11-14 03:37:39,072 INFO: Reading image
# MainProcess 2025-11-14 03:38:21,771 INFO: Reading segmentation mask
# MainProcess 2025-11-14 05:34:05,646 INFO: Quantifying markers before correction
# MainProcess 2025-11-14 05:34:13,821 INFO: Creating cell-cell contact matrix
# MainProcess 2025-11-14 05:38:04,064 INFO: Performing correction
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# MainProcess 2025-11-14 06:57:05,227 INFO: Writing output files to /mnt/jwh83-data/Confetti/output/Redsea/MicroSAM/B004-A-404
# MainProcess 2025-11-14 06:57:43,324 INFO: Done

# %%
# !redsea \
  /mnt/jwh83-data/Confetti/data/CODEX/new/done/B004-A-408.tif \
  /mnt/jwh83-data/Confetti/output/intestine_data_mask_outputs/MicroSAM/B004-A-408-msamtif.tif \
  /mnt/jwh83-data/Confetti/data/CODEX/ns_mp_codex_channel_list.csv \
  /mnt/jwh83-data/Confetti/output/Redsea/MicroSAM/B004-A-408 \
  --element-shape star \
  --element-size 2
# Out:
# MainProcess 2025-11-14 06:57:43,847 INFO: Reading image
# MainProcess 2025-11-14 06:58:27,600 INFO: Reading segmentation mask
# MainProcess 2025-11-14 08:25:03,794 INFO: Quantifying markers before correction
# MainProcess 2025-11-14 08:25:09,409 INFO: Creating cell-cell contact matrix
# MainProcess 2025-11-14 08:29:00,721 INFO: Performing correction
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# MainProcess 2025-11-14 09:32:18,688 INFO: Writing output files to /mnt/jwh83-data/Confetti/output/Redsea/MicroSAM/B004-A-408
# MainProcess 2025-11-14 09:32:21,050 INFO: Done

# %%
# !redsea \
  /mnt/jwh83-data/Confetti/data/CODEX/new/done/B004-A-504.tif \
  /mnt/jwh83-data/Confetti/output/intestine_data_mask_outputs/MicroSAM/B004-A-504-msamtif.tif \
  /mnt/jwh83-data/Confetti/data/CODEX/ns_mp_codex_channel_list.csv \
  /mnt/jwh83-data/Confetti/output/Redsea/MicroSAM/B004-A-504 \
  --element-shape star \
  --element-size 2
# Out:
# MainProcess 2025-11-14 12:08:53,279 INFO: Reading image
# MainProcess 2025-11-14 12:09:38,029 INFO: Reading segmentation mask
# MainProcess 2025-11-14 14:18:02,488 INFO: Quantifying markers before correction
# MainProcess 2025-11-14 14:18:10,376 INFO: Creating cell-cell contact matrix
# MainProcess 2025-11-14 14:22:39,464 INFO: Performing correction
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# MainProcess 2025-11-14 16:10:41,980 INFO: Writing output files to /mnt/jwh83-data/Confetti/output/Redsea/MicroSAM/B004-A-504
# MainProcess 2025-11-14 16:10:46,090 INFO: Done
